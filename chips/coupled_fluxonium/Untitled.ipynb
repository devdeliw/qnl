# %%
from qiskit_metal import draw, Dict, MetalGUI, designs
from collections import OrderedDict
import numpy as np
from qiskit_metal.toolbox_metal.parsing import parse_value
from components.coupling_resonator_ import resonator

# %%
design = designs.DesignPlanar() 
design.overwrite_enabled = True 

# %load_ext autoreload 
# %autoreload 2

gui = MetalGUI(design)
# Out:
# 09:58PM 00s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: Populating font family aliases took 187 ms. Replace uses of missing font family "Courier" with one that exists to avoid this cost.

# %%
resonator(design, 0, -5, name='resonator', key='lower_left')

# %%
gui.rebuild() 
gui.autoscale()
# Out:
# 2025-04-12 21:58:01.178 python[44751:2321384] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-04-12 21:58:01.179 python[44751:2321384] +[IMKInputSession subclass]: chose IMKInputSession_Modern
