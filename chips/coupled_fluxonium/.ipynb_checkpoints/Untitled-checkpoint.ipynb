# %%
from qiskit_metal import draw, Dict, MetalGUI, designs
from qiskit_metal.qlibrary.QNLMetal.fluxline import FluxLine

# %%
design = designs.DesignPlanar() 
design.overwrite_enabled = True 

# %load_ext autoreload 
# %autoreload 2

gui = MetalGUI(design)
# Out:
# 04:29AM 46s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: Populating font family aliases took 187 ms. Replace uses of missing font family "Courier" with one that exists to avoid this cost.

# %%
fl = FluxLine(design)

# %%
gui.rebuild() 
gui.autoscale()

# %%
fl.position('wide_gap_center', (0.4, 0.3))
